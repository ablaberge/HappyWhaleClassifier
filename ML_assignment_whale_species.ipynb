# %% [markdown]
# # Image Classification ML Assignment
#
# The goal of this assignment is to learn fundamentals of machine learning and image analysis. You will analyze images from Happy Whale, an organization that tracks whales globally, and modify a classifier for these images.
#
# Part 1: Walk through (Due Feb 27)
# - In class, we will walk through the provided code
# - This script has several functions that are written for you. For part 1, please do NOT modify any code unless it specifies to change it.
# - Answer the questions as you go through the code
#
# Part 2: Make modifications (Due Feb 27)
# - Change model parameters or other model aspects at least 3 times
# - Describe what happened when you made these changes
#
# Part 3: Create a team, get inspired and try a new approach to your model (Due March 6)
# - Have a group meeting and record your meeting with audio or video (you can record with zoom!)
#     - Start by discussing part 2 of the assignment:
#         - What approaches you each took to change the ML model in part 2
#         - What are similarities and differences between your approaches
#         - What types of changes improved model performance
#         - What types of changes made model performance worse
#         - Based on the whole group's work, what would y'all want to do next in terms of model optimization?
#     - Next, look at code and approaches from the [Happy Whales competition leaderboard](https://www.kaggle.com/competitions/happy-whale-and-dolphin/leaderboard).
#         - Is there any strategy that someone used that you could implement?
#             - Ex: learning rate value, # epochs, transformation strategy, or more complex changes to the models
#         - Are there strategies that you are interested in learning about?
#     - Lastly, make a plan for 1 more round of model optimization
#         - Assign each member something to attempt for training the model. Use your cumulative experience to decide the most important things to test.
#         - Group members can make as small as changing the value for a parameter or as big as changing the model.
# - Have each member complete their test
# - Share results with each other
# - Write a 1-3 paragraph summary on your group's attempts and recommendations moving forward
# - For Part 3: Turn in the audio/video recording of the group meeting, each member's code (uploaded to their original git repo), and the team's 1-3 paragraph summary over canvas.

# %% [markdown]
# ### Your choices on data
# You can chose between 3 datasets for this assignment. This jupyter notebook is set up using the Species dataset. If you change the dataset, you will need to change the number of classes parameter for the model.
# - Species = you will classify images by species (gray, killer, beluga, humpback, false killer, and common dolphin)
#   - File path: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species
# - Species_all = you will classify images by species (minke, gray, killer, beluga, humpback, false killer, and bottlenose and common dolphin). There are a high number of images for bottlenose dolphins and minke whales which leads to this dataset being quite large. Due to the size of the dataset, it has a longer training time than the "Species" dataset.
#   - File path: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species_all
#   - Num classes: 8
# - Individuals = you will classify images by individuals. This is a much more challenging classification task because you have different individuals from different species. However, this was the original goal of the Happy Whale competition, so try challenging yourself to this important task!
#   - File path: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/individuals
#   - Num classes: 110
#
# You are NOT graded by the success of your model, so you are free to train the model on whichever dataset is more interesting to you. However, **everyone on your team for part 3 should be using the same dataset**.

# %% [markdown]
# ### Part 1

# %%
## Importing packages - Please DO NOT alter this box ##
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
from torch.utils.data.sampler import WeightedRandomSampler
torch.manual_seed(0)

from captum.attr import IntegratedGradients
from captum.attr import DeepLift
from captum.attr import NoiseTunnel
from captum.attr import visualization as viz

import torchvision
from torchvision import datasets, transforms
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

import os
import imageio
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from tqdm import tqdm
from scipy.ndimage import binary_erosion
import pandas as pd
from sklearn.metrics import confusion_matrix
import seaborn as sns

import wandb #comment this out if you are not using weights and biases
import random #comment this out if you are not using weights and biases

# Set device to cuda if it's available otherwise default to "cpu"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ### Loading in the dataset
#
# By default, this will load in the species dataset, this is the smallest dataset (i.e., it will be relatively fast to train) and has a simple goal (i.e., you will be able to create an accurate model). If you want a challenge, I highly encourage you to try the Species_all (a dataset with 2 additional species) or the individual dataset (a dataset where whales are characterized by individual rather than species).

# %%
images = "/projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species"

# %%
# We must turn our images into tensors, resize, and normalize them 
# We can also add additional transformations to images 
transform = transforms.Compose([transforms.ToTensor(), 
                                #We will start with a model called Resnet18 that is optimized for 224x224 images
                                #It is set to a very SMALL size initially so the model will train fast in class
                                transforms.Resize([224,224]),
                                transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]) # Normalize the data, these are the values that ResNet suggests based on their training data (natural scences)
                               ])
all_images = datasets.ImageFolder(images, transform)
print(all_images)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 2794
#     Root location: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Resize(size=[224, 224], interpolation=bilinear, max_size=None, antialias=True)
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %% [markdown]
# <font color='magenta'>What is the purpose(s) of transforming image data? (2 pts)

# %% [markdown]
# Transforming the data helps to standardize the images, improve model performance, and artificially expand the data set.

# %% [markdown]
# <font color='green'>The below code completes the image transformations as coded in the above box.

# %%
all_images = datasets.ImageFolder(images, transform )
print(len(all_images))
print(all_images)
# Out:
# 2794
# Dataset ImageFolder
#     Number of datapoints: 2794
#     Root location: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Resize(size=[224, 224], interpolation=bilinear, max_size=None, antialias=True)
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %% [markdown]
# Our classification labels will be converted to indices, we can determine which indices is which label using the below code

# %%
print(all_images.class_to_idx)
# Out:
# {'beluga': 0, 'common_dolphin': 1, 'false_killer_whale': 2, 'fin_whale': 3, 'gray_whale': 4, 'humpback_whale': 5}

# %% [markdown]
# <font color='green'>The below function is used to randomly select dataset images to evaluate how the transformations altered the images.

# %%
def show_random_dataset_image(dataset):
    idx = np.random.randint(0, len(dataset))    # take a random sample
    img, mask = dataset[idx]                    # get the image and the nuclei masks
    f, axarr = plt.subplots(1, 2)               # make two plots on one figure
    axarr[0].imshow(img[0], cmap="viridis")                     # show the image, cmap is the color map that the image is being shown in
    #axarr[1].imshow(mask[0])                    # show the masks
    _ = [ax.axis('off') for ax in axarr]        # remove the axes
    print('Image size is %s' % {img[0].shape})
    print(img.shape)
    plt.show()

# %%
show_random_dataset_image(all_images)
# Out:
# Image size is {torch.Size([224, 224])}
# torch.Size([3, 224, 224])

# %% [markdown]
# <font color='magenta'>What is the difference between image size and torch image size? (2 pts)

# %% [markdown]
# Image size represents the height and width of the image while torch size represents the number of channels (R,G,B in this case) in addition to height and width.

# %% [markdown]
# <font color='magenta'>Add a new transformation to the training data. After your first run of this model during class time, resize the image to 224x224 pixels. (2 pts)

# %%
## ADD YOUR TRANSFORMATION HERE
transform = transforms.Compose([transforms.ColorJitter(brightness=.5, hue=.3),
            transforms.Resize([224,224]), # Resize the image as our model is optimized for 224x224 pixels
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])]) # Normalize the data, these are the values that ResNet suggests based on their training data (natural scences))

all_images = datasets.ImageFolder(images, transform )
show_random_dataset_image(all_images)
# Out:
# Image size is {torch.Size([224, 224])}
# torch.Size([3, 224, 224])

# %% [markdown]
# <font color='magenta'>How did your transformation impact the images? (1 pt)

# %% [markdown]
# My transformation used ColorJitter, so it randomly changed the brightness and hue of the images +- 0.5 brightness and +- 0.3 hue.

# %% [markdown]
# ### Creating datasets used in training and testing
#
# After loading in the data, we separate the data into training, validation, and testing datasets. The training data is inputted into the model during the training phase, and the model's predictions from this data is used to modulate the weights of the model. The validation data is used while the model trains, but the model is in a evaluation rather than training mode. The validation data gives us a real time view on how accurately the model is predicting our labels. The testing data is used after the model has completed training and tells us how successful our model will be with a novel dataset.
#
# Once creating these 3 datasets, we prepare dataloaders which are used to load the images into our models. These images are loaded in batches into the model (a parameter called batch size). Because our dataset is imbalanced, we use a weighted random sampler to select images for our batches in the dataloader. Therefore to create our dataloader, we start by creating a function to get weights, calculating weights, initiating our weighted random sampler, and then creating our dataloaders.

# %% [markdown]
# <font color='green'>The below code eastablishes the data split between training, validation, and testing.

# %%
train_size = int(0.7 * len(all_images))
val_size = int(0.15 * len(all_images))
test_size = len(all_images) - (train_size + val_size)
print(train_size, val_size, test_size)
assert train_size + val_size + test_size == len(all_images)
# Out:
# 1955 419 420

# %%
train_set, val_set, test_set = torch.utils.data.random_split(all_images, [train_size, val_size, test_size])

# %% [markdown]
# <font color='green'>The below function is used to get weights for the image classes.

# %%
def _get_weights(subset,full_dataset):
    ys = np.array([y for _, y in subset])
    counts = np.bincount(ys)
    label_weights = 1.0 / counts
    weights = label_weights[ys]

    print("Number of images per class:")
    for c, n, w in zip(full_dataset.classes, counts, label_weights):
        print(f"\t{c}:\tn={n}\tweight={w}")
        
    return weights

# %%
train_weights = _get_weights(train_set,all_images)
train_sampler = WeightedRandomSampler(train_weights, len(train_weights))
# Out:
# Number of images per class:
# 	beluga:	n=475	weight=0.002105263157894737
# 	common_dolphin:	n=50	weight=0.02
# 	false_killer_whale:	n=722	weight=0.0013850415512465374
# 	fin_whale:	n=122	weight=0.00819672131147541
# 	gray_whale:	n=55	weight=0.01818181818181818
# 	humpback_whale:	n=531	weight=0.0018832391713747645

# %% [markdown]
# <font color='magenta'>What is the impact of the class weight on how data is loaded into the model? What does it mean if a class has a low vs high weight? (2 pts)

# %% [markdown]
# <details>
#   <summary>Hint</summary>
#
# Check out this resource: https://towardsdatascience.com/demystifying-pytorchs-weightedrandomsampler-by-example-a68aceccb452

# %% [markdown]
# Class weight determines how much mistakes are penalized during training for each class. A high weight means mistakes are penalized more greatly and the model is forced it learn it better, whereas a low weight allows for more mistakes with a given class. A lot of times, these are determined by the number of samples in each class with the minority class getting a higher weight than the majority class.

# %%
train_loader = DataLoader(train_set, batch_size=48, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=48, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=48, drop_last=True, shuffle=True)

# %% [markdown]
# ### Picking hyperparameters
#
# We can set a few hyperparameters that we decide and can tune. These include:
#
# - Learning rate = how much to update our model's parameters at each batch/epoch
# - batch size = the number of data samples to pass through the network before updating it
#     - If you change the batchsize below, make sure you ALSO change it in the commands above for the DataLoader
# - Number of epochs = # of times to iterate over the dataset in model training

# %%
learning_rate=1e-3
batchsize=48
epochs=5

# %% [markdown]
# <font color='magenta'>How would model training be impacted if we decreased our learning rate? What about if we increased it? (2 pts)

# %% [markdown]
# If we decreased our learning rate, the model might get stuck in local minima or take a very long time to converge. Conversely, if we chose a higher learning rate, the model might experience overcorrection and learn "too quickly" to identify neccesary features.

# %% [markdown]
# ### Training our model
#
# For part 1, we are going to use the model ResNet18. This is a published model for imaging data. Resnet18 is built from 4 residual blocks with two convolutional layers (Conv2d). Each convolutional layer is followed by a batch normalization step (BatchNorm2D) and a ReLU activation layer (ReLU). There is also a shortcut connection which adds input to output and allows the network to learn residual mapping.
#
# I provided the complete code for the ResNet18 model. In the future, if you want to use resnet18, you can load it simply by running `resnet18_model = torchvision.models.resnet18(weights = False, progress  = True, num_classes=XXX)`. We will look at the full code for the model so you can see how this model was created.

# %% [markdown]
# <font color='green'>The below code builds the residual blocks that ResNet18 uses in the model.

# %%
## First, we create the basic block that will be used in our residual net
class BasicBlock(nn.Module):
    # Initializing method for the basic block (It's OOP!)
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        ## Conv1: convolution layer, batch normalization, ReLU activation
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

        ## Conv2: convolution layer, batch normalization
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        ## Shortcut connection: adds input to output
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    # The forward method calls on each layer
    def forward(self, x):
        ## Conv1: convolution layer, batch normalization, ReLU activation
        out = self.conv1(x) 
        out = self.bn1(out)
        out = self.relu(out)
        ## Conv2: convolution layer, batch normalization
        out = self.conv2(out)
        out = self.bn2(out)
        ## Shortcut connection
        out += self.shortcut(x)
        ## Final activation
        out = self.relu(out)
        return out

# %% [markdown]
# <font color='green'>The below code builds and initializes the ResNet18 model.

# %%
## Next, we put together these building blocks and create our residual net
class ResNet18(nn.Module):
    # specify the number of classes that we are predicting
    def __init__(self, num_classes=6):
        super(ResNet18, self).__init__()
        # In channels = Num pixels in H + Num pixels in W
        self.in_channels = 64
        
        # First convolution set (convolution, batch norm, relu)
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu = nn.ReLU(inplace=True)

        # Our building blocks
        # The numbers correspond to the matrix shape
        ### We increase the number of filters/channels (i.e., the first number) as we go
        self.layer1 = self._make_layer(BasicBlock, 64, 2, stride=1)
        self.layer2 = self._make_layer(BasicBlock, 128, 2, stride=2)
        self.layer3 = self._make_layer(BasicBlock, 256, 2, stride=2)
        self.layer4 = self._make_layer(BasicBlock, 512, 2, stride=2)

        # Average pooling 
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

        # Final layer that makes the classification
        self.fc = nn.Linear(512, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        # First convolution set (convolution, batch norm, relu)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        # Our 4 building blocks
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        # Final layer that makes the classification
        out = self.fc(out)
        return out

## Getting our model and transferring it to the GPU
model = ResNet18().to(device)
print(model)
# Out:
# ResNet18(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=6, bias=True)
# )

# %% [markdown]
# <font color='green'>The below code eastablishes the loss function and optimizer used in training the model.

# %%
#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# <font color='green'>The below functions are used to train, evaluate, and test the Machine Learning model.

# %%
wandb.login()
wandb.init(
    project="BGMP_HappyWhale",
    name="Annika-HappyWhale-SpeciesDataset-hyperparameters", ### Update with your name!
    config={"learning rate":0.001,
        "architecture": "CNN",
        "dataset": "Species",
        "epochs":5}
)

num_epochs = epochs
train_losses, train_acc_list, val_losses, val_acc_list = [], [], [],[]

for epoch in range(num_epochs):
    # Setting model to "training mode"
    model.train()
    running_loss = 0.0
    correct, total = 0, 0
    batch=0

    # For each batch of data within the loader
    for inputs, labels in train_loader:
        # Send our input images and their labels to the GPU
        inputs, labels = inputs.to(device), labels.to(device)
        # Zero the gradients
        optimizer.zero_grad()
        # Inputting our training images into the model
        # and Predicting the image classification label
        outputs = model(inputs)
        # Figuring out the loss from our predictions
        loss = criterion(outputs, labels)
        # Compute gradients (aka backward pass)
        loss.backward()
        # Update model parameters
        optimizer.step()

        # Adding the loss to our running sum
        # Loss is calculated for each batch within an epoch
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        batch+=1
        print(f'Epoch [{epoch+1}/{num_epochs}] | Batch #{batch} | Batch Accuracy {(correct/total)*100:.2f}%')


    # Getting metrics for our training pass 
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_acc_list.append(train_acc)
    
    # Switching our model to "evaluation mode"
    model.eval()
    running_loss = 0.0
    correct, total = 0, 0
    # Disable gradient calculation b/c we are evalulating the model
    with torch.no_grad():
        # Load in batches of our validation data
        for inputs, labels in val_loader:
            # Send test images and labels to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
            # Predict the image classification label
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            # Figuring out how many predicted labels = true labels
            correct += predicted.eq(labels).sum().item()

            # Figuring out the loss from our predictions
            loss = criterion(outputs, labels)
            # Adding the loss to our running sum
            # Loss is calculated for each batch within an epoch
            running_loss += loss.item() * inputs.size(0)
    # Getting our accuracy from our test data
    val_acc = 100. * correct / total
    val_acc_list.append(val_acc)
    # Getting the loss from our test data
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.2f}%')

    # log metrics to wandb
    wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})

wandb.finish()
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/alaberge/.netrc.
# wandb: Currently logged in as: alaberge (BGMP_HappyWhale) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/gpfs/home/alaberge/HappyWhaleClassifier/wandb/run-20260225_133559-1kk9frlw</code>
# Syncing run <strong><a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/1kk9frlw' target="_blank">Annika-HappyWhale-SpeciesDataset-hyperparameters</a></strong> to <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a>
#  View run at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/1kk9frlw' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/1kk9frlw</a>
# Epoch [1/5] | Batch #1 | Batch Accuracy 27.08%
# Epoch [1/5] | Batch #2 | Batch Accuracy 18.75%
# Epoch [1/5] | Batch #3 | Batch Accuracy 18.06%
# Epoch [1/5] | Batch #4 | Batch Accuracy 20.83%
# Epoch [1/5] | Batch #5 | Batch Accuracy 20.42%
# Epoch [1/5] | Batch #6 | Batch Accuracy 22.57%
# Epoch [1/5] | Batch #7 | Batch Accuracy 23.81%
# Epoch [1/5] | Batch #8 | Batch Accuracy 23.70%
# Epoch [1/5] | Batch #9 | Batch Accuracy 25.69%
# Epoch [1/5] | Batch #10 | Batch Accuracy 27.71%
# Epoch [1/5] | Batch #11 | Batch Accuracy 28.79%
# Epoch [1/5] | Batch #12 | Batch Accuracy 28.99%
# Epoch [1/5] | Batch #13 | Batch Accuracy 29.17%
# Epoch [1/5] | Batch #14 | Batch Accuracy 29.02%
# Epoch [1/5] | Batch #15 | Batch Accuracy 28.47%
# Epoch [1/5] | Batch #16 | Batch Accuracy 28.91%
# Epoch [1/5] | Batch #17 | Batch Accuracy 29.04%
# Epoch [1/5] | Batch #18 | Batch Accuracy 30.09%
# Epoch [1/5] | Batch #19 | Batch Accuracy 30.26%
# Epoch [1/5] | Batch #20 | Batch Accuracy 30.52%
# Epoch [1/5] | Batch #21 | Batch Accuracy 31.05%
# Epoch [1/5] | Batch #22 | Batch Accuracy 31.44%
# Epoch [1/5] | Batch #23 | Batch Accuracy 31.43%
# Epoch [1/5] | Batch #24 | Batch Accuracy 31.77%
# Epoch [1/5] | Batch #25 | Batch Accuracy 31.92%
# Epoch [1/5] | Batch #26 | Batch Accuracy 32.29%
# Epoch [1/5] | Batch #27 | Batch Accuracy 32.18%
# Epoch [1/5] | Batch #28 | Batch Accuracy 32.59%
# Epoch [1/5] | Batch #29 | Batch Accuracy 32.83%
# Epoch [1/5] | Batch #30 | Batch Accuracy 32.99%
# Epoch [1/5] | Batch #31 | Batch Accuracy 33.40%
# Epoch [1/5] | Batch #32 | Batch Accuracy 33.46%
# Epoch [1/5] | Batch #33 | Batch Accuracy 33.65%
# Epoch [1/5] | Batch #34 | Batch Accuracy 34.25%
# Epoch [1/5] | Batch #35 | Batch Accuracy 34.23%
# Epoch [1/5] | Batch #36 | Batch Accuracy 34.09%
# Epoch [1/5] | Batch #37 | Batch Accuracy 34.35%
# Epoch [1/5] | Batch #38 | Batch Accuracy 34.54%
# Epoch [1/5] | Batch #39 | Batch Accuracy 34.88%
# Epoch [1/5] | Batch #40 | Batch Accuracy 35.57%
# Epoch [1/5] Train Loss: 1.6984 | Train Acc: 35.57% | Val Acc: 22.40% | Val Loss: 2.08%
# Epoch [2/5] | Batch #1 | Batch Accuracy 41.67%
# Epoch [2/5] | Batch #2 | Batch Accuracy 36.46%
# Epoch [2/5] | Batch #3 | Batch Accuracy 38.89%
# Epoch [2/5] | Batch #4 | Batch Accuracy 41.67%
# Epoch [2/5] | Batch #5 | Batch Accuracy 40.42%
# Epoch [2/5] | Batch #6 | Batch Accuracy 40.97%
# Epoch [2/5] | Batch #7 | Batch Accuracy 42.26%
# Epoch [2/5] | Batch #8 | Batch Accuracy 42.97%
# Epoch [2/5] | Batch #9 | Batch Accuracy 44.68%
# Epoch [2/5] | Batch #10 | Batch Accuracy 43.12%
# Epoch [2/5] | Batch #11 | Batch Accuracy 43.18%
# Epoch [2/5] | Batch #12 | Batch Accuracy 43.23%
# Epoch [2/5] | Batch #13 | Batch Accuracy 42.15%
# Epoch [2/5] | Batch #14 | Batch Accuracy 42.26%
# Epoch [2/5] | Batch #15 | Batch Accuracy 41.94%
# Epoch [2/5] | Batch #16 | Batch Accuracy 42.32%
# Epoch [2/5] | Batch #17 | Batch Accuracy 42.16%
# Epoch [2/5] | Batch #18 | Batch Accuracy 41.44%
# Epoch [2/5] | Batch #19 | Batch Accuracy 41.67%
# Epoch [2/5] | Batch #20 | Batch Accuracy 41.67%
# Epoch [2/5] | Batch #21 | Batch Accuracy 41.87%
# Epoch [2/5] | Batch #22 | Batch Accuracy 41.76%
# Epoch [2/5] | Batch #23 | Batch Accuracy 42.21%
# Epoch [2/5] | Batch #24 | Batch Accuracy 42.71%
# Epoch [2/5] | Batch #25 | Batch Accuracy 42.67%
# Epoch [2/5] | Batch #26 | Batch Accuracy 43.03%
# Epoch [2/5] | Batch #27 | Batch Accuracy 42.98%
# Epoch [2/5] | Batch #28 | Batch Accuracy 42.78%
# Epoch [2/5] | Batch #29 | Batch Accuracy 42.89%
# Epoch [2/5] | Batch #30 | Batch Accuracy 42.92%
# Epoch [2/5] | Batch #31 | Batch Accuracy 43.35%
# Epoch [2/5] | Batch #32 | Batch Accuracy 43.42%
# Epoch [2/5] | Batch #33 | Batch Accuracy 43.31%
# Epoch [2/5] | Batch #34 | Batch Accuracy 43.20%
# Epoch [2/5] | Batch #35 | Batch Accuracy 43.21%
# Epoch [2/5] | Batch #36 | Batch Accuracy 43.34%
# Epoch [2/5] | Batch #37 | Batch Accuracy 43.58%
# Epoch [2/5] | Batch #38 | Batch Accuracy 44.02%
# Epoch [2/5] | Batch #39 | Batch Accuracy 44.55%
# Epoch [2/5] | Batch #40 | Batch Accuracy 44.95%
# Epoch [2/5] Train Loss: 1.4112 | Train Acc: 44.95% | Val Acc: 42.45% | Val Loss: 1.32%
# Epoch [3/5] | Batch #1 | Batch Accuracy 54.17%
# Epoch [3/5] | Batch #2 | Batch Accuracy 56.25%
# Epoch [3/5] | Batch #3 | Batch Accuracy 56.25%
# Epoch [3/5] | Batch #4 | Batch Accuracy 54.69%
# Epoch [3/5] | Batch #5 | Batch Accuracy 55.42%
# Epoch [3/5] | Batch #6 | Batch Accuracy 54.17%
# Epoch [3/5] | Batch #7 | Batch Accuracy 55.06%
# Epoch [3/5] | Batch #8 | Batch Accuracy 53.39%
# Epoch [3/5] | Batch #9 | Batch Accuracy 51.85%
# Epoch [3/5] | Batch #10 | Batch Accuracy 50.83%
# Epoch [3/5] | Batch #11 | Batch Accuracy 50.95%
# Epoch [3/5] | Batch #12 | Batch Accuracy 51.39%
# Epoch [3/5] | Batch #13 | Batch Accuracy 51.12%
# Epoch [3/5] | Batch #14 | Batch Accuracy 50.15%
# Epoch [3/5] | Batch #15 | Batch Accuracy 50.28%
# Epoch [3/5] | Batch #16 | Batch Accuracy 50.26%
# Epoch [3/5] | Batch #17 | Batch Accuracy 50.74%
# Epoch [3/5] | Batch #18 | Batch Accuracy 50.58%
# Epoch [3/5] | Batch #19 | Batch Accuracy 50.33%
# Epoch [3/5] | Batch #20 | Batch Accuracy 50.31%
# Epoch [3/5] | Batch #21 | Batch Accuracy 49.21%
# Epoch [3/5] | Batch #22 | Batch Accuracy 49.34%
# Epoch [3/5] | Batch #23 | Batch Accuracy 48.91%
# Epoch [3/5] | Batch #24 | Batch Accuracy 49.05%
# Epoch [3/5] | Batch #25 | Batch Accuracy 48.75%
# Epoch [3/5] | Batch #26 | Batch Accuracy 48.96%
# Epoch [3/5] | Batch #27 | Batch Accuracy 49.07%
# Epoch [3/5] | Batch #28 | Batch Accuracy 48.66%
# Epoch [3/5] | Batch #29 | Batch Accuracy 48.78%
# Epoch [3/5] | Batch #30 | Batch Accuracy 48.61%
# Epoch [3/5] | Batch #31 | Batch Accuracy 48.32%
# Epoch [3/5] | Batch #32 | Batch Accuracy 48.31%
# Epoch [3/5] | Batch #33 | Batch Accuracy 48.23%
# Epoch [3/5] | Batch #34 | Batch Accuracy 48.16%
# Epoch [3/5] | Batch #35 | Batch Accuracy 48.15%
# Epoch [3/5] | Batch #36 | Batch Accuracy 47.86%
# Epoch [3/5] | Batch #37 | Batch Accuracy 47.52%
# Epoch [3/5] | Batch #38 | Batch Accuracy 47.70%
# Epoch [3/5] | Batch #39 | Batch Accuracy 47.54%
# Epoch [3/5] | Batch #40 | Batch Accuracy 47.66%
# Epoch [3/5] Train Loss: 1.3500 | Train Acc: 47.66% | Val Acc: 45.57% | Val Loss: 1.25%
# Epoch [4/5] | Batch #1 | Batch Accuracy 41.67%
# Epoch [4/5] | Batch #2 | Batch Accuracy 35.42%
# Epoch [4/5] | Batch #3 | Batch Accuracy 42.36%
# Epoch [4/5] | Batch #4 | Batch Accuracy 43.23%
# Epoch [4/5] | Batch #5 | Batch Accuracy 44.17%
# Epoch [4/5] | Batch #6 | Batch Accuracy 45.49%
# Epoch [4/5] | Batch #7 | Batch Accuracy 45.24%
# Epoch [4/5] | Batch #8 | Batch Accuracy 44.79%
# Epoch [4/5] | Batch #9 | Batch Accuracy 45.60%
# Epoch [4/5] | Batch #10 | Batch Accuracy 46.46%
# Epoch [4/5] | Batch #11 | Batch Accuracy 45.83%
# Epoch [4/5] | Batch #12 | Batch Accuracy 45.83%
# Epoch [4/5] | Batch #13 | Batch Accuracy 45.51%
# Epoch [4/5] | Batch #14 | Batch Accuracy 46.88%
# Epoch [4/5] | Batch #15 | Batch Accuracy 47.64%
# Epoch [4/5] | Batch #16 | Batch Accuracy 47.14%
# Epoch [4/5] | Batch #17 | Batch Accuracy 47.18%
# Epoch [4/5] | Batch #18 | Batch Accuracy 47.11%
# Epoch [4/5] | Batch #19 | Batch Accuracy 47.59%
# Epoch [4/5] | Batch #20 | Batch Accuracy 47.92%
# Epoch [4/5] | Batch #21 | Batch Accuracy 48.31%
# Epoch [4/5] | Batch #22 | Batch Accuracy 48.01%
# Epoch [4/5] | Batch #23 | Batch Accuracy 48.01%
# Epoch [4/5] | Batch #24 | Batch Accuracy 47.83%
# Epoch [4/5] | Batch #25 | Batch Accuracy 48.08%
# Epoch [4/5] | Batch #26 | Batch Accuracy 47.76%
# Epoch [4/5] | Batch #27 | Batch Accuracy 47.99%
# Epoch [4/5] | Batch #28 | Batch Accuracy 48.29%
# Epoch [4/5] | Batch #29 | Batch Accuracy 47.92%
# Epoch [4/5] | Batch #30 | Batch Accuracy 47.85%
# Epoch [4/5] | Batch #31 | Batch Accuracy 47.51%
# Epoch [4/5] | Batch #32 | Batch Accuracy 47.72%
# Epoch [4/5] | Batch #33 | Batch Accuracy 47.35%
# Epoch [4/5] | Batch #34 | Batch Accuracy 46.94%
# Epoch [4/5] | Batch #35 | Batch Accuracy 47.14%
# Epoch [4/5] | Batch #36 | Batch Accuracy 47.45%
# Epoch [4/5] | Batch #37 | Batch Accuracy 47.30%
# Epoch [4/5] | Batch #38 | Batch Accuracy 47.31%
# Epoch [4/5] | Batch #39 | Batch Accuracy 47.12%
# Epoch [4/5] | Batch #40 | Batch Accuracy 47.19%
# Epoch [4/5] Train Loss: 1.3545 | Train Acc: 47.19% | Val Acc: 45.05% | Val Loss: 1.45%
# Epoch [5/5] | Batch #1 | Batch Accuracy 60.42%
# Epoch [5/5] | Batch #2 | Batch Accuracy 51.04%
# Epoch [5/5] | Batch #3 | Batch Accuracy 43.75%
# Epoch [5/5] | Batch #4 | Batch Accuracy 41.15%
# Epoch [5/5] | Batch #5 | Batch Accuracy 41.25%
# Epoch [5/5] | Batch #6 | Batch Accuracy 42.71%
# Epoch [5/5] | Batch #7 | Batch Accuracy 43.45%
# Epoch [5/5] | Batch #8 | Batch Accuracy 44.27%
# Epoch [5/5] | Batch #9 | Batch Accuracy 44.44%
# Epoch [5/5] | Batch #10 | Batch Accuracy 45.62%
# Epoch [5/5] | Batch #11 | Batch Accuracy 45.83%
# Epoch [5/5] | Batch #12 | Batch Accuracy 46.01%
# Epoch [5/5] | Batch #13 | Batch Accuracy 45.51%
# Epoch [5/5] | Batch #14 | Batch Accuracy 45.24%
# Epoch [5/5] | Batch #15 | Batch Accuracy 45.69%
# Epoch [5/5] | Batch #16 | Batch Accuracy 46.22%
# Epoch [5/5] | Batch #17 | Batch Accuracy 46.69%
# Epoch [5/5] | Batch #18 | Batch Accuracy 47.22%
# Epoch [5/5] | Batch #19 | Batch Accuracy 47.26%
# Epoch [5/5] | Batch #20 | Batch Accuracy 46.88%
# Epoch [5/5] | Batch #21 | Batch Accuracy 47.22%
# Epoch [5/5] | Batch #22 | Batch Accuracy 47.82%
# Epoch [5/5] | Batch #23 | Batch Accuracy 48.10%
# Epoch [5/5] | Batch #24 | Batch Accuracy 48.26%
# Epoch [5/5] | Batch #25 | Batch Accuracy 48.08%
# Epoch [5/5] | Batch #26 | Batch Accuracy 47.52%
# Epoch [5/5] | Batch #27 | Batch Accuracy 47.69%
# Epoch [5/5] | Batch #28 | Batch Accuracy 48.07%
# Epoch [5/5] | Batch #29 | Batch Accuracy 48.20%
# Epoch [5/5] | Batch #30 | Batch Accuracy 47.85%
# Epoch [5/5] | Batch #31 | Batch Accuracy 47.72%
# Epoch [5/5] | Batch #32 | Batch Accuracy 47.79%
# Epoch [5/5] | Batch #33 | Batch Accuracy 47.60%
# Epoch [5/5] | Batch #34 | Batch Accuracy 47.43%
# Epoch [5/5] | Batch #35 | Batch Accuracy 47.20%
# Epoch [5/5] | Batch #36 | Batch Accuracy 47.45%
# Epoch [5/5] | Batch #37 | Batch Accuracy 47.47%
# Epoch [5/5] | Batch #38 | Batch Accuracy 47.53%
# Epoch [5/5] | Batch #39 | Batch Accuracy 47.65%
# Epoch [5/5] | Batch #40 | Batch Accuracy 47.45%
# Epoch [5/5] Train Loss: 1.3551 | Train Acc: 47.45% | Val Acc: 53.12% | Val Loss: 1.19%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>█▂▁▁▁</td></tr><tr><td>validation_accuracy</td><td>▁▆▆▆█</td></tr><tr><td>validation_loss</td><td>█▂▂▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>1.35514</td></tr><tr><td>validation_accuracy</td><td>53.125</td></tr><tr><td>validation_loss</td><td>1.18792</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Annika-HappyWhale-SpeciesDataset-hyperparameters</strong> at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/1kk9frlw' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/1kk9frlw</a><br> View project at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a><br>Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260225_133559-1kk9frlw/logs</code>

# %% [markdown]
# #### For our class training, run the below model and consider the success of the model training.
#
# <font color='magenta'>What is your starting accuracy and final accuracy? What happened to the model to change the accuracy from epoch 1 to 5? (2 pts)

# %% [markdown]
# Starting accuracy: 22.40
# Final accuracy: 53.13
# Over the course of the epochs, the model was penalized each time it identified a species incorrectly or "rewarded" when a species was identified correctly. This was done using the weights we identified earlier. This process took place for all images during each epoch, and at the end of each epoch, the testing set was used to see how our model generalized to unseen data.

# %%
plt.plot(range(num_epochs), val_acc_list, color = "magenta")
plt.xlabel("Epoch number")
plt.ylabel("Valiation accuracy")
plt.show()  

plt.plot(range(num_epochs), val_losses, color = "purple")
plt.xlabel("Epoch number")
plt.ylabel("Valiation loss")
plt.show()

# %% [markdown]
# <font color='green'>After running the model and calculating the overall accuracy, we can examine the data via a confusion matrix which highlights the accuracy by class.

# %%
# predict the test dataset
def predict(model, dataset):
    dataset_prediction = []
    dataset_groundtruth = []
    model = model
    with torch.no_grad():
        for x, y_true in dataset:
            inp = x[None]
            y_pred = model(inp)
            dataset_prediction.append(y_pred.argmax().cpu().numpy())
            dataset_groundtruth.append(y_true)
    
    return np.array(dataset_prediction), np.array(dataset_groundtruth)
            
    # create seaborn heatmap with required labels
    ax=sns.heatmap(cm, annot=annot, fmt='', vmax=30, xticklabels=x_axis_labels, yticklabels=y_axis_labels)
    ax.set_title(title)

# Plot confusion matrix 
# orginally from Runqi Yang; 
# see https://gist.github.com/hitvoice/36cf44689065ca9b927431546381a3f7
def cm_analysis(y_true, y_pred, title, figsize=(10,10)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    labels = ['Beluga','Common dolphin', 'False killer whale', 'Fin whale', 'Gray whale','Humpback whale']
    cm = confusion_matrix(y_true, y_pred)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
                              
    x_axis_labels = ['Beluga','Common dolphin', 'False killer whale', 'Fin whale', 'Gray whale','Humpback whale'] # labels for x-axis
    y_axis_labels = ['Beluga','Common dolphin', 'False killer whale', 'Fin whale', 'Gray whale','Humpback whale'] # labels for y-axis
    ax=sns.heatmap(cm, annot=annot, fmt='', vmax=30, xticklabels=x_axis_labels, yticklabels=y_axis_labels, cmap = "viridis")
    ax.set_title(title)

## This plot only contains the test set of data
## The test set of data has not been seen by the model yet
y_pred, y_true = predict(model, test_set)

print(y_true)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# [0 2 2 0 2 0 3 5 2 5 2 2 5 0 1 5 2 2 2 2 1 2 2 2 2 5 1 0 0 2 0 2 5 5 2 5 4
#  5 5 5 5 2 0 0 2 5 0 0 5 5 5 5 1 2 0 2 0 1 5 5 2 5 5 2 0 0 2 5 2 0 2 3 5 2
#  5 4 2 5 3 3 0 2 5 5 0 5 2 5 5 0 2 5 0 5 5 5 1 2 2 5 0 0 2 5 1 2 2 2 2 5 0
#  3 0 4 0 5 2 5 2 0 2 2 2 5 2 0 5 5 2 4 2 0 2 0 0 5 5 3 5 0 5 2 0 2 2 5 0 2
#  2 5 0 2 5 2 5 2 5 0 0 1 5 5 2 2 0 2 5 0 5 0 0 5 2 0 2 2 2 2 5 0 5 0 0 2 5
#  5 5 2 3 0 0 3 2 3 0 3 5 5 2 5 5 2 5 2 0 0 5 2 5 3 5 5 2 5 2 5 2 2 3 5 2 2
#  5 2 5 0 2 2 2 0 3 0 2 0 5 5 2 5 5 5 2 5 2 2 0 5 2 2 5 0 0 2 5 2 5 2 5 0 0
#  0 2 2 5 2 2 2 2 5 2 2 0 2 4 4 5 0 0 2 3 5 0 5 2 0 5 2 0 5 2 2 2 5 2 2 5 2
#  2 1 2 0 2 0 2 2 2 5 2 2 2 2 0 2 3 0 2 5 2 5 2 5 5 4 5 5 2 5 0 0 2 0 5 2 0
#  2 2 5 3 5 0 5 5 0 2 2 2 1 2 1 2 2 0 2 2 5 5 0 5 5 5 5 0 5 2 5 5 3 5 0 5 2
#  5 0 2 1 2 3 5 3 0 3 0 5 2 0 0 2 0 0 2 5 5 0 0 0 2 0 0 0 0 0 3 2 5 5 3 2 2
#  0 2 3 2 5 5 2 5 2 4 5 2 2]
# /tmp/ipykernel_2329329/2764316866.py:50: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)

# %% [markdown]
# ### What features did the model use to make decisions?
#
# Based on the confusion matrices and validation loss, it is clear that the model is learning. To determine the features that are involved in decision making, there are a few possible approaches. One options is shown below, integrated gradients.

# %% [markdown]
# #### Understanding feature importance using Integrated Gradients
#
# <font color='green'>Integrated gradients is an attribution method. Attribution methods score the input data based on the prediction that the model makes using scores for each feature. The gradient is the signal that tells the network how much to increase or decrease a certain weight in the network during backpropogation. These gradients are overlaid onto the images to showcase the regions on the images that influence the weights.
#
# Run the below code.

# %%
def visualize_ig(idx, 
                 _train_dataset=train_set, 
                 _test_dataset=test_set):
        
    # Get corresponding input and target tensors:
    input_tensor = _test_dataset[idx][0].unsqueeze(0)
    input_tensor.requires_grad = True
    target = _test_dataset[idx][1]
    
    # We will use the IntegratedGradients algorithm:
    algorithm = IntegratedGradients(model)
    
    # First we clear the gradients from the model:
    model.zero_grad()
    
    # Run attribution:
    attr_ig, delta = algorithm.attribute(input_tensor,
                                          target=target,
                                          baselines=input_tensor * 0,
                                          return_convergence_delta=True
                                        )
    
    # Integrated Gradients:
    attr_ig = np.transpose(attr_ig[0].cpu().detach().numpy(), (1, 2, 0))
    
    # Original image:
    original_image = np.transpose((_test_dataset[idx][0].detach().numpy() * 0.5) + 0.5, (1, 2, 0))
    
    print("Annotated whale species", test_true[idx])
    plt.imshow(original_image)
    
    
    print("Predicted whale species", test_pred[idx])


    # This visualises the attribution of labels to 
    viz.visualize_image_attr(attr_ig, 
                             original_image, 
                             method="blended_heat_map",
                             sign="all",
                             show_colorbar=True, 
                             title="Overlayed Integrated Gradients")

test_pred, test_true = predict(model, test_set)

visualize_ig(0)
visualize_ig(8)
visualize_ig(20)
visualize_ig(32)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..0.7045316].
# Annotated whale species 0
# Predicted whale species 3
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5161401..1.5759914].
# Annotated whale species 2
# Predicted whale species 2
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.43051636..1.82].
# Annotated whale species 1
# Predicted whale species 3
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.32776785..1.7851416].
# Annotated whale species 5
# Predicted whale species 0

# %% [markdown]
# <font color='magenta'>Does the integrated gradient show what types of features the model used to classify the images? Do you notice any potential problems? (2 pts)

# %% [markdown]
# The integrated gradient shows that landscapes included in the image were sometimes being used to classify the species which is likely one source of error. Additionally, the shape of the dorsal fil, which should be an important feature and therefore always outlined as green in these plots, is sometimes outlined in red, likely accounting for another source of error.

# %% [markdown]
# ## Part 2
#
# Now that you have a sense for how to train a machine learning model, your task is to improve the success of our classification model.
#
# **In three separate training events, make one (or more) modifications to the model training process, re-train the model, and report out your changes and whether they increased model accuracy. Why did you chose your particular change (curiousity, hypothesis, ect.)? Do you have ideas why your modifications were/were not successful?**
#
# Types of changes that you can make include:
# - [Using the pre-trained weights for ResNet18 (transfer learning)](https://docs.pytorch.org/vision/main/models/generated/torchvision.models.resnet18.html)
# - Changing hyperparameters (learning rate, batch size)
# - [Changing transformation approach](https://docs.pytorch.org/vision/0.11/auto_examples/plot_transforms.html#sphx-glr-auto-examples-plot-transforms-py)
# - [Changing the optimizer](https://docs.pytorch.org/docs/stable/optim.html)
# - [Changing the model to a different pre-made model architecture](https://docs.pytorch.org/vision/main/models.html)
# - Modifying the ResNet18 model
# - Coming up with a whole new model!
#
# If you decide to change any lines of code that are not in the below box, please add them to the box (DO NOT MODIFY ANY CODE ABOVE THIS MARKDOWN BOX - IT MAY BREAK PART 1).
#
# If your changes are ambitious, the code may take hours to run. If this is the case, please consider turning this notebook into a python script and running it via sBATCH.
#
# **Please note, you will NOT be graded by the success of your classifiers! It is okay if you are unable to improve the accuracy of the classifier**

# %% [markdown]
# #### Your Model 1 (10 pts)

# %% [markdown]
# <font color='magenta'>Describe your changes to the model training process (either changing something about the model, a hyperparameter, how data was inputted into the model, or another aspect) and why you selected those changes.

# %% [markdown]
# I maintained the same batchsize but increased learning rate to 0.01 and decreased epochs to 3 to see if we could get the model to train faster while still maintaining the same, or nearly the same, level of accuracy.

# %%
batchsize = 48
learning_rate=1e-2
epochs=3

train_loader = DataLoader(train_set, batch_size=batchsize, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=batchsize, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=batchsize, drop_last=True, shuffle=True)

# %%
## Model
#########
## First, we create the basic block that will be used in our residual net
class BasicBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        ## Conv1: convolution layer, batch normalization, ReLU activation
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

        ## Conv2: convolution layer, batch normalization
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        ## Shortcut connection: adds input to output
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    # The forward method calls on each layer
    def forward(self, x):
        ## Conv1: convolution layer, batch normalization, ReLU activation
        out = self.conv1(x) 
        out = self.bn1(out)
        out = self.relu(out)
        ## Conv2: convolution layer, batch normalization
        out = self.conv2(out)
        out = self.bn2(out)
        ## Shortcut connection
        out += self.shortcut(x)
        ## Final activation
        out = self.relu(out)
        return out

############
## Next, we put together these building blocks and create our residual net
class ResNet18(nn.Module):
    # specify the number of classes that we are predicting
    def __init__(self, num_classes=6):
        super(ResNet18, self).__init__()
        # In channels = Num pixels in H + Num pixels in W
        self.in_channels = 64
        
        # First convolution set (convolution, batch norm, relu)
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu = nn.ReLU(inplace=True)

        # Our building blocks
        # The numbers correspond to the matrix shape
        ### We increase the number of filters/channels (i.e., the first number) as we go
        self.layer1 = self._make_layer(BasicBlock, 64, 2, stride=1)
        self.layer2 = self._make_layer(BasicBlock, 128, 2, stride=2)
        self.layer3 = self._make_layer(BasicBlock, 256, 2, stride=2)
        self.layer4 = self._make_layer(BasicBlock, 512, 2, stride=2)

        # Average pooling 
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

        # Final layer that makes the classification
        self.fc = nn.Linear(512, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        # First convolution set (convolution, batch norm, relu)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        # Our 4 building blocks
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        # Final layer that makes the classification
        out = self.fc(out)
        return out

## Getting our model and transferring it to the GPU
model = ResNet18().to(device)

#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
wandb.init(
    project="BGMP_HappyWhale",
    name="Annika-HappyWhale-SpeciesDataset-hyperparameters_mod1", ##update this with your name
    config={"learning rate":.01, # possibly update
        "architecture": "CNN",
        "dataset": "Species",
        "epochs": 3, "batch_size":48}  # possibly update
) 

batch=0
num_epochs = epochs
train_losses, train_acc_list, val_losses, val_acc_list = [], [], [],[]

for epoch in range(num_epochs):
    # Setting model to "training mode"
    model.train()
    running_loss = 0.0
    correct, total = 0, 0

    # For each batch of data within the loader
    for inputs, labels in train_loader:
        # Send our input images and their labels to the GPU
        inputs, labels = inputs.to(device), labels.to(device)
        # Zero the gradients
        optimizer.zero_grad()
        # Inputting our training images into the model
        # and Predicting the image classification label
        outputs = model(inputs)
        # Figuring out the loss from our predictions
        loss = criterion(outputs, labels)
        # Compute gradients (aka backward pass)
        loss.backward()
        # Update model parameters
        optimizer.step()

        # Adding the loss to our running sum
        # Loss is calculated for each batch within an epoch
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        batch+=1
        print(f'Epoch [{epoch+1}/{num_epochs}] | Batch #{batch} | Batch Accuracy {(correct/total)*100:.2f}%')


    # Getting metrics for our training pass 
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_acc_list.append(train_acc)
    
    # Switching our model to "evaluation mode"
    model.eval()
    running_loss = 0.0
    correct, total = 0, 0
    # Disable gradient calculation b/c we are evalulating the model
    with torch.no_grad():
        # Load in batches of our validation data
        for inputs, labels in val_loader:
            # Send test images and labels to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
            # Predict the image classification label
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            # Figuring out how many predicted labels = true labels
            correct += predicted.eq(labels).sum().item()

            # Figuring out the loss from our predictions
            loss = criterion(outputs, labels)
            # Adding the loss to our running sum
            # Loss is calculated for each batch within an epoch
            running_loss += loss.item() * inputs.size(0)
    # Getting our accuracy from our test data
    val_acc = 100. * correct / total
    val_acc_list.append(val_acc)
    # Getting the loss from our test data
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.2f}%')

    # log metrics to wandb
    wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})

wandb.finish()

plt.plot(range(epochs), val_acc_list, color = "magenta")
plt.xlabel("Epoch number")
plt.ylabel("Valiation accuracy")
plt.show()  

plt.plot(range(epochs), val_losses, color = "purple")
plt.xlabel("Epoch number")
plt.ylabel("Valiation loss")
plt.show()  

y_pred, y_true = predict(model, test_set)
cm_analysis(y_true, y_pred, "Confusion matrix")

# %% [markdown]
# ![Mod1.png](attachment:f2e2c992-67a5-436a-a5c4-04e8863bd563.png)

# %% [markdown]
# ![Mod1](Mod1CM.png)

# %% [markdown]
# <font color='magenta'>Were your changes successful? Do you have ideas why your changes were successful or not?

# %% [markdown]
# My changes were not successful; accuracy plummeted early and did not come back up. I suspect this is because of the increased learning rate, which overshot the optimal value and resulted in overgeneralization of each image's features. If it were due to the decreased number of epochs, we would see some improvement in accuracy over each epoch, but instead, we see that the accuracy gets worse with each epoch (though it did begin to improve during epoch 3). Yikes!

# %% [markdown]
# #### Your Model 2 (10pts)

# %% [markdown]
# <font color='magenta'>Describe your changes to the model training process (either changing something about the model, a hyperparameter, how data was inputted into the model, or another aspect) and why you selected those changes.

# %% [markdown]
# I wanted to see what might happen if I returned the learning rate to its original value of 0.001 while still decreasing epochs to 3 and holding batch size at the original value of 48. Maybe this will still get us a model comparable in accuracy to model 0 while training faster?

# %%
batchsize = 48
learning_rate=1e-3
epochs=3

train_loader = DataLoader(train_set, batch_size=batchsize, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=batchsize, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=batchsize, drop_last=True, shuffle=True)

# %%
## Model
#########
## First, we create the basic block that will be used in our residual net
class BasicBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        ## Conv1: convolution layer, batch normalization, ReLU activation
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

        ## Conv2: convolution layer, batch normalization
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        ## Shortcut connection: adds input to output
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    # The forward method calls on each layer
    def forward(self, x):
        ## Conv1: convolution layer, batch normalization, ReLU activation
        out = self.conv1(x) 
        out = self.bn1(out)
        out = self.relu(out)
        ## Conv2: convolution layer, batch normalization
        out = self.conv2(out)
        out = self.bn2(out)
        ## Shortcut connection
        out += self.shortcut(x)
        ## Final activation
        out = self.relu(out)
        return out

############
## Next, we put together these building blocks and create our residual net
class ResNet18(nn.Module):
    # specify the number of classes that we are predicting
    def __init__(self, num_classes=6):
        super(ResNet18, self).__init__()
        # In channels = Num pixels in H + Num pixels in W
        self.in_channels = 64
        
        # First convolution set (convolution, batch norm, relu)
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu = nn.ReLU(inplace=True)

        # Our building blocks
        # The numbers correspond to the matrix shape
        ### We increase the number of channels (i.e., the first number) as we go
        self.layer1 = self._make_layer(BasicBlock, 64, 2, stride=1)
        self.layer2 = self._make_layer(BasicBlock, 128, 2, stride=2)
        self.layer3 = self._make_layer(BasicBlock, 256, 2, stride=2)
        self.layer4 = self._make_layer(BasicBlock, 512, 2, stride=2)

        # Average pooling 
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

        # Final layer that makes the classification
        self.fc = nn.Linear(512, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        # First convolution set (convolution, batch norm, relu)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        # Our 4 building blocks
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        # Final layer that makes the classification
        out = self.fc(out)
        return out

## Getting our model and transferring it to the GPU
model = ResNet18().to(device)

#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
wandb.init(
    project="BGMP_HappyWhale",
    name="Annika-HappyWhale-SpeciesDataset-hyperparameters_mod2", ##update this with your name
    config={"learning rate":.001, # possibly update
        "architecture": "CNN",
        "dataset": "Species",
        "epochs": 3, "batch_size":48}  # possibly update
) 

batch=0
num_epochs = epochs
train_losses, train_acc_list, val_losses, val_acc_list = [], [], [],[]

for epoch in range(num_epochs):
    # Setting model to "training mode"
    model.train()
    running_loss = 0.0
    correct, total = 0, 0

    # For each batch of data within the loader
    for inputs, labels in train_loader:
        # Send our input images and their labels to the GPU
        inputs, labels = inputs.to(device), labels.to(device)
        # Zero the gradients
        optimizer.zero_grad()
        # Inputting our training images into the model
        # and Predicting the image classification label
        outputs = model(inputs)
        # Figuring out the loss from our predictions
        loss = criterion(outputs, labels)
        # Compute gradients (aka backward pass)
        loss.backward()
        # Update model parameters
        optimizer.step()

        # Adding the loss to our running sum
        # Loss is calculated for each batch within an epoch
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        batch+=1
        print(f'Epoch [{epoch+1}/{num_epochs}] | Batch #{batch} | Batch Accuracy {(correct/total)*100:.2f}%')


    # Getting metrics for our training pass 
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_acc_list.append(train_acc)
    
    # Switching our model to "evaluation mode"
    model.eval()
    running_loss = 0.0
    correct, total = 0, 0
    # Disable gradient calculation b/c we are evalulating the model
    with torch.no_grad():
        # Load in batches of our validation data
        for inputs, labels in val_loader:
            # Send test images and labels to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
            # Predict the image classification label
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            # Figuring out how many predicted labels = true labels
            correct += predicted.eq(labels).sum().item()

            # Figuring out the loss from our predictions
            loss = criterion(outputs, labels)
            # Adding the loss to our running sum
            # Loss is calculated for each batch within an epoch
            running_loss += loss.item() * inputs.size(0)
    # Getting our accuracy from our test data
    val_acc = 100. * correct / total
    val_acc_list.append(val_acc)
    # Getting the loss from our test data
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.2f}%')

    # log metrics to wandb
    wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})

wandb.finish()
# Out:
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/gpfs/home/alaberge/HappyWhaleClassifier/wandb/run-20260225_165726-13k8jos0</code>
# Syncing run <strong><a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/13k8jos0' target="_blank">Annika-HappyWhale-SpeciesDataset-hyperparameters_mod2</a></strong> to <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a>
#  View run at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/13k8jos0' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/13k8jos0</a>
# Epoch [1/3] | Batch #1 | Batch Accuracy 14.58%
# Epoch [1/3] | Batch #2 | Batch Accuracy 20.83%
# Epoch [1/3] | Batch #3 | Batch Accuracy 17.36%
# Epoch [1/3] | Batch #4 | Batch Accuracy 16.67%
# Epoch [1/3] | Batch #5 | Batch Accuracy 16.25%
# Epoch [1/3] | Batch #6 | Batch Accuracy 18.40%
# Epoch [1/3] | Batch #7 | Batch Accuracy 18.75%
# Epoch [1/3] | Batch #8 | Batch Accuracy 20.31%
# Epoch [1/3] | Batch #9 | Batch Accuracy 21.06%
# Epoch [1/3] | Batch #10 | Batch Accuracy 21.46%
# Epoch [1/3] | Batch #11 | Batch Accuracy 23.11%
# Epoch [1/3] | Batch #12 | Batch Accuracy 24.65%
# Epoch [1/3] | Batch #13 | Batch Accuracy 25.96%
# Epoch [1/3] | Batch #14 | Batch Accuracy 26.19%
# Epoch [1/3] | Batch #15 | Batch Accuracy 26.94%
# Epoch [1/3] | Batch #16 | Batch Accuracy 27.21%
# Epoch [1/3] | Batch #17 | Batch Accuracy 28.06%
# Epoch [1/3] | Batch #18 | Batch Accuracy 28.47%
# Epoch [1/3] | Batch #19 | Batch Accuracy 28.73%
# Epoch [1/3] | Batch #20 | Batch Accuracy 29.27%
# Epoch [1/3] | Batch #21 | Batch Accuracy 30.06%
# Epoch [1/3] | Batch #22 | Batch Accuracy 30.68%
# Epoch [1/3] | Batch #23 | Batch Accuracy 31.43%
# Epoch [1/3] | Batch #24 | Batch Accuracy 31.94%
# Epoch [1/3] | Batch #25 | Batch Accuracy 32.17%
# Epoch [1/3] | Batch #26 | Batch Accuracy 32.21%
# Epoch [1/3] | Batch #27 | Batch Accuracy 32.25%
# Epoch [1/3] | Batch #28 | Batch Accuracy 32.44%
# Epoch [1/3] | Batch #29 | Batch Accuracy 32.54%
# Epoch [1/3] | Batch #30 | Batch Accuracy 32.57%
# Epoch [1/3] | Batch #31 | Batch Accuracy 32.59%
# Epoch [1/3] | Batch #32 | Batch Accuracy 32.68%
# Epoch [1/3] | Batch #33 | Batch Accuracy 32.58%
# Epoch [1/3] | Batch #34 | Batch Accuracy 32.72%
# Epoch [1/3] | Batch #35 | Batch Accuracy 32.80%
# Epoch [1/3] | Batch #36 | Batch Accuracy 32.87%
# Epoch [1/3] | Batch #37 | Batch Accuracy 32.66%
# Epoch [1/3] | Batch #38 | Batch Accuracy 32.51%
# Epoch [1/3] | Batch #39 | Batch Accuracy 32.85%
# Epoch [1/3] | Batch #40 | Batch Accuracy 32.76%
# Epoch [1/3] Train Loss: 1.7420 | Train Acc: 32.76% | Val Acc: 32.81% | Val Loss: 1.33%
# Epoch [2/3] | Batch #41 | Batch Accuracy 37.50%
# Epoch [2/3] | Batch #42 | Batch Accuracy 43.75%
# Epoch [2/3] | Batch #43 | Batch Accuracy 40.97%
# Epoch [2/3] | Batch #44 | Batch Accuracy 40.10%
# Epoch [2/3] | Batch #45 | Batch Accuracy 38.75%
# Epoch [2/3] | Batch #46 | Batch Accuracy 40.28%
# Epoch [2/3] | Batch #47 | Batch Accuracy 40.18%
# Epoch [2/3] | Batch #48 | Batch Accuracy 39.84%
# Epoch [2/3] | Batch #49 | Batch Accuracy 40.28%
# Epoch [2/3] | Batch #50 | Batch Accuracy 40.42%
# Epoch [2/3] | Batch #51 | Batch Accuracy 39.20%
# Epoch [2/3] | Batch #52 | Batch Accuracy 39.76%
# Epoch [2/3] | Batch #53 | Batch Accuracy 39.42%
# Epoch [2/3] | Batch #54 | Batch Accuracy 39.88%
# Epoch [2/3] | Batch #55 | Batch Accuracy 39.31%
# Epoch [2/3] | Batch #56 | Batch Accuracy 39.19%
# Epoch [2/3] | Batch #57 | Batch Accuracy 39.34%
# Epoch [2/3] | Batch #58 | Batch Accuracy 39.70%
# Epoch [2/3] | Batch #59 | Batch Accuracy 39.69%
# Epoch [2/3] | Batch #60 | Batch Accuracy 39.69%
# Epoch [2/3] | Batch #61 | Batch Accuracy 40.58%
# Epoch [2/3] | Batch #62 | Batch Accuracy 40.62%
# Epoch [2/3] | Batch #63 | Batch Accuracy 40.49%
# Epoch [2/3] | Batch #64 | Batch Accuracy 40.71%
# Epoch [2/3] | Batch #65 | Batch Accuracy 40.33%
# Epoch [2/3] | Batch #66 | Batch Accuracy 40.62%
# Epoch [2/3] | Batch #67 | Batch Accuracy 40.74%
# Epoch [2/3] | Batch #68 | Batch Accuracy 40.62%
# Epoch [2/3] | Batch #69 | Batch Accuracy 40.80%
# Epoch [2/3] | Batch #70 | Batch Accuracy 41.04%
# Epoch [2/3] | Batch #71 | Batch Accuracy 40.86%
# Epoch [2/3] | Batch #72 | Batch Accuracy 40.56%
# Epoch [2/3] | Batch #73 | Batch Accuracy 40.34%
# Epoch [2/3] | Batch #74 | Batch Accuracy 40.44%
# Epoch [2/3] | Batch #75 | Batch Accuracy 40.42%
# Epoch [2/3] | Batch #76 | Batch Accuracy 40.16%
# Epoch [2/3] | Batch #77 | Batch Accuracy 39.92%
# Epoch [2/3] | Batch #78 | Batch Accuracy 40.19%
# Epoch [2/3] | Batch #79 | Batch Accuracy 40.28%
# Epoch [2/3] | Batch #80 | Batch Accuracy 40.42%
# Epoch [2/3] Train Loss: 1.4652 | Train Acc: 40.42% | Val Acc: 40.10% | Val Loss: 1.41%
# Epoch [3/3] | Batch #81 | Batch Accuracy 50.00%
# Epoch [3/3] | Batch #82 | Batch Accuracy 44.79%
# Epoch [3/3] | Batch #83 | Batch Accuracy 45.14%
# Epoch [3/3] | Batch #84 | Batch Accuracy 44.27%
# Epoch [3/3] | Batch #85 | Batch Accuracy 42.08%
# Epoch [3/3] | Batch #86 | Batch Accuracy 41.67%
# Epoch [3/3] | Batch #87 | Batch Accuracy 42.86%
# Epoch [3/3] | Batch #88 | Batch Accuracy 42.97%
# Epoch [3/3] | Batch #89 | Batch Accuracy 43.52%
# Epoch [3/3] | Batch #90 | Batch Accuracy 44.17%
# Epoch [3/3] | Batch #91 | Batch Accuracy 43.75%
# Epoch [3/3] | Batch #92 | Batch Accuracy 43.92%
# Epoch [3/3] | Batch #93 | Batch Accuracy 43.11%
# Epoch [3/3] | Batch #94 | Batch Accuracy 42.86%
# Epoch [3/3] | Batch #95 | Batch Accuracy 41.81%
# Epoch [3/3] | Batch #96 | Batch Accuracy 42.06%
# Epoch [3/3] | Batch #97 | Batch Accuracy 42.52%
# Epoch [3/3] | Batch #98 | Batch Accuracy 42.82%
# Epoch [3/3] | Batch #99 | Batch Accuracy 43.53%
# Epoch [3/3] | Batch #100 | Batch Accuracy 43.75%
# Epoch [3/3] | Batch #101 | Batch Accuracy 44.44%
# Epoch [3/3] | Batch #102 | Batch Accuracy 44.41%
# Epoch [3/3] | Batch #103 | Batch Accuracy 44.66%
# Epoch [3/3] | Batch #104 | Batch Accuracy 44.79%
# Epoch [3/3] | Batch #105 | Batch Accuracy 44.83%
# Epoch [3/3] | Batch #106 | Batch Accuracy 45.03%
# Epoch [3/3] | Batch #107 | Batch Accuracy 45.14%
# Epoch [3/3] | Batch #108 | Batch Accuracy 44.49%
# Epoch [3/3] | Batch #109 | Batch Accuracy 44.18%
# Epoch [3/3] | Batch #110 | Batch Accuracy 44.31%
# Epoch [3/3] | Batch #111 | Batch Accuracy 44.49%
# Epoch [3/3] | Batch #112 | Batch Accuracy 44.21%
# Epoch [3/3] | Batch #113 | Batch Accuracy 44.13%
# Epoch [3/3] | Batch #114 | Batch Accuracy 44.12%
# Epoch [3/3] | Batch #115 | Batch Accuracy 44.17%
# Epoch [3/3] | Batch #116 | Batch Accuracy 44.27%
# Epoch [3/3] | Batch #117 | Batch Accuracy 43.98%
# Epoch [3/3] | Batch #118 | Batch Accuracy 44.35%
# Epoch [3/3] | Batch #119 | Batch Accuracy 44.71%
# Epoch [3/3] | Batch #120 | Batch Accuracy 44.64%
# Epoch [3/3] Train Loss: 1.4074 | Train Acc: 44.64% | Val Acc: 38.28% | Val Loss: 1.34%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>█▂▁</td></tr><tr><td>validation_accuracy</td><td>▁█▆</td></tr><tr><td>validation_loss</td><td>▁█▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>1.40739</td></tr><tr><td>validation_accuracy</td><td>38.28125</td></tr><tr><td>validation_loss</td><td>1.34279</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Annika-HappyWhale-SpeciesDataset-hyperparameters_mod2</strong> at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/13k8jos0' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/13k8jos0</a><br> View project at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a><br>Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260225_165726-13k8jos0/logs</code>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 93
#      90 plt.ylabel("Valiation accuracy")
#      91 plt.show()
# ---> 93 plt.plot(range(epochs), validation_losses, color = "purple")
#      94 plt.xlabel("Epoch number")
#      95 plt.ylabel("Valiation loss")
#
# NameError: name 'validation_losses' is not defined

# %%
plt.plot(range(epochs), val_acc_list, color = "magenta")
plt.xlabel("Epoch number")
plt.ylabel("Valiation accuracy")
plt.show()  

plt.plot(range(epochs), val_losses, color = "purple")
plt.xlabel("Epoch number")
plt.ylabel("Valiation loss")
plt.show()  

y_pred, y_true = predict(model, test_set)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# /tmp/ipykernel_2329329/2764316866.py:50: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)

# %% [markdown]
# <font color='magenta'>Were your changes successful? Do you have ideas why your changes were successful or not?

# %% [markdown]
# This model did better than model 1, but ultimately did not reach the same accuracy as model 0. This leads me to believe number of epochs is one of the most important hyperparameters at play because decreasing epochs took a bit chunk out of the accuracy.

# %% [markdown]
# #### Your Model 3 (10 pts)

# %% [markdown]
# <font color='magenta'>Describe your changes to the model training process (either changing something about the model, a hyperparameter, how data was inputted into the model, or another aspect) and why you selected those changes.

# %% [markdown]
# Since I identified that an increased number of epochs is a really important hyperparameter for increasing accuracy, I want to see what happens when I add 2 additional epochs to model 0 hyperparameters, while all else remains constant.

# %%
# predict the test dataset
def predict(model, dataset):
    dataset_prediction = []
    dataset_groundtruth = []
    model = model
    with torch.no_grad():
        for x, y_true in dataset:
            inp = x[None]
            y_pred = model(inp)
            dataset_prediction.append(y_pred.argmax().cpu().numpy())
            dataset_groundtruth.append(y_true)
    
    return np.array(dataset_prediction), np.array(dataset_groundtruth)
            
    # create seaborn heatmap with required labels
    ax=sns.heatmap(cm, annot=annot, fmt='', vmax=30, xticklabels=x_axis_labels, yticklabels=y_axis_labels)
    ax.set_title(title)

# %%
batchsize = 48
learning_rate=1e-3
epochs=7

train_loader = DataLoader(train_set, batch_size=batchsize, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=batchsize, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=batchsize, drop_last=True, shuffle=True)

# %%
## Model
#########
## First, we create the basic block that will be used in our residual net
class BasicBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        ## Conv1: convolution layer, batch normalization, ReLU activation
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

        ## Conv2: convolution layer, batch normalization
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        ## Shortcut connection: adds input to output
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    # The forward method calls on each layer
    def forward(self, x):
        ## Conv1: convolution layer, batch normalization, ReLU activation
        out = self.conv1(x) 
        out = self.bn1(out)
        out = self.relu(out)
        ## Conv2: convolution layer, batch normalization
        out = self.conv2(out)
        out = self.bn2(out)
        ## Shortcut connection
        out += self.shortcut(x)
        ## Final activation
        out = self.relu(out)
        return out

############
## Next, we put together these building blocks and create our residual net
class ResNet18(nn.Module):
    # specify the number of classes that we are predicting
    def __init__(self, num_classes=6):
        super(ResNet18, self).__init__()
        # In channels = Num pixels in H + Num pixels in W
        self.in_channels = 64
        
        # First convolution set (convolution, batch norm, relu)
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu = nn.ReLU(inplace=True)

        # Our building blocks
        # The numbers correspond to the matrix shape
        ### We increase the number of channels (i.e., the first number) as we go
        self.layer1 = self._make_layer(BasicBlock, 64, 2, stride=1)
        self.layer2 = self._make_layer(BasicBlock, 128, 2, stride=2)
        self.layer3 = self._make_layer(BasicBlock, 256, 2, stride=2)
        self.layer4 = self._make_layer(BasicBlock, 512, 2, stride=2)

        # Average pooling 
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

        # Final layer that makes the classification
        self.fc = nn.Linear(512, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        # First convolution set (convolution, batch norm, relu)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        # Our 4 building blocks
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        # Final layer that makes the classification
        out = self.fc(out)
        return out

## Getting our model and transferring it to the GPU
model = ResNet18().to(device)

#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
wandb.init(
    project="BGMP_HappyWhale",
    name="Annika-HappyWhale-SpeciesDataset-hyperparameters_mod3", ##update this with your name
    config={"learning rate":.001, # possibly update
        "architecture": "CNN",
        "dataset": "Species",
        "epochs": 7, "batch_size":48}  # possibly update
) 

batch=0
num_epochs = epochs
train_losses, train_acc_list, val_losses, val_acc_list = [], [], [],[]

for epoch in range(num_epochs):
    # Setting model to "training mode"
    model.train()
    running_loss = 0.0
    correct, total = 0, 0

    # For each batch of data within the loader
    for inputs, labels in train_loader:
        # Send our input images and their labels to the GPU
        inputs, labels = inputs.to(device), labels.to(device)
        # Zero the gradients
        optimizer.zero_grad()
        # Inputting our training images into the model
        # and Predicting the image classification label
        outputs = model(inputs)
        # Figuring out the loss from our predictions
        loss = criterion(outputs, labels)
        # Compute gradients (aka backward pass)
        loss.backward()
        # Update model parameters
        optimizer.step()

        # Adding the loss to our running sum
        # Loss is calculated for each batch within an epoch
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        batch+=1
        print(f'Epoch [{epoch+1}/{num_epochs}] | Batch #{batch} | Batch Accuracy {(correct/total)*100:.2f}%')


    # Getting metrics for our training pass 
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_acc_list.append(train_acc)
    
    # Switching our model to "evaluation mode"
    model.eval()
    running_loss = 0.0
    correct, total = 0, 0
    # Disable gradient calculation b/c we are evalulating the model
    with torch.no_grad():
        # Load in batches of our validation data
        for inputs, labels in val_loader:
            # Send test images and labels to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
            # Predict the image classification label
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            # Figuring out how many predicted labels = true labels
            correct += predicted.eq(labels).sum().item()

            # Figuring out the loss from our predictions
            loss = criterion(outputs, labels)
            # Adding the loss to our running sum
            # Loss is calculated for each batch within an epoch
            running_loss += loss.item() * inputs.size(0)
    # Getting our accuracy from our test data
    val_acc = 100. * correct / total
    val_acc_list.append(val_acc)
    # Getting the loss from our test data
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.2f}%')

    # log metrics to wandb
    wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})

wandb.finish()

plt.plot(range(epochs), val_acc, color = "magenta")
plt.xlabel("Epoch number")
plt.ylabel("Valiation accuracy")
plt.show()  

plt.plot(range(epochs), val_losses, color = "purple")
plt.xlabel("Epoch number")
plt.ylabel("Valiation loss")
plt.show()  

y_pred, y_true = predict(model, test_set)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/alaberge/.netrc.
# wandb: Currently logged in as: alaberge (BGMP_HappyWhale) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/gpfs/home/alaberge/HappyWhaleClassifier/wandb/run-20260225_185910-wjjlnley</code>
# Syncing run <strong><a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/wjjlnley' target="_blank">Annika-HappyWhale-SpeciesDataset-hyperparameters_mod3</a></strong> to <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a>
#  View run at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/wjjlnley' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/wjjlnley</a>
# Epoch [1/7] | Batch #1 | Batch Accuracy 20.83%
# Epoch [1/7] | Batch #2 | Batch Accuracy 15.62%

# %% [markdown]
# ![Mod3 Validation Accuracy](Mod3_ValAcc.png)
# ![Mod3 Validation Loss](Mod3_ValLoss.png)

# %% [markdown]
# <font color='magenta'>Were your changes successful? Do you have ideas why your changes were successful or not?

# %% [markdown]
# Interestingly, while we would expect an increased number of epochs, with all other hyperparameters and transformations remaining constant, to increase validation accuracy and minimize validation loss, this was not seen. Validation accuracy was lower for model 3 than model 0, and validation loss was higher. This is likely due to the minimal number of epochs comparable to what we would use to train a deployable model in a real-world scenario (i.e., 100+ epochs). With a greater number of epochs comes increased stability over model training, but in this case, our randomly chosen filter weights just happened to be selected as poorer values in model 3 compared to model 0, resulting in a more poorly performing model despite the extra 2 epochs.

# %% [markdown]
# <font color='magenta'>Summarize your 3 steps, their success, and what you learned (5 pts)

# %% [markdown]
# For my first model, I decided to reduce the number of epochs while increasing the learning rate, resulting in the lowest-performing model in terms of validation accuracy. Next, I decided to decrease the learning rate back to 0.001 while still reducing the number of epochs compared to model 0. This resulted in a slightly better model compared to model 2, but final validation accuracy was still lower than either model 0 or model 3. Finally, I chose to increase the number of epochs to 7 for model 3 while leaving the learning rate at 0.001. While this model performed better than either model 1 or model 2, it ultimately did not reach the validation accuracy that model 0 did.
#
# I learned a lot. A big takeaway for me is that the number of epochs should be very large when training a model in a real-world scenario. Additionally, I realized how detrimental it can be to the model's performance when the learning rate isn't optimized. Overshooting this can cause huge issues with overgeneralization, while undershooting it can slow down the model's training or even prevent it from converging entirely.
